# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt('/Users/oonaghparker/Downloads/DISSO/22/orbit_22_1.txt')

# %%
plt.scatter(data[:,1],data[:,2])

# %%
stream_arr = [1,12,16,51,34,38,40,49,53,66]
shell_arr = [2,3,6,33,9,7,13,14,12,11,8,37,21,36,47,48,52,17,4,70,63,46,50,43,45,26,58]

# %%
data = np.genfromtxt('/Users/oonaghparker/Downloads/DISSO/22/orbit_22_1.txt'.format(cid1))
plt.plot(data[:,1]-data[:,1][-1],data[:,2],c='b',label='Stream')
plt.xlabel('Lookback Time (Gyr)', fontsize=15)
plt.ylabel('Radius (kpc)', fontsize=15)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlim(left=-12, right=-2.33)
plt.ylim(bottom=0, top=350)
apo_stream = np.append(apo_stream,np.max(data[:,2][i:]))
peri_stream = np.append(peri_stream,np.min(data[:,2][i:]))

data2 = np.genfromtxt('/Users/oonaghparker/Downloads/DISSO/22/orbit_22_2.txt'.format(cid1))
plt.plot(data2[:,1]-data2[:,1][-1],data2[:,2],c='r',label='Shell')
plt.xlabel('Lookback Time (Gyr)', fontsize=15)
plt.ylabel('Radius (kpc)', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlim(left=-12, right=-2.33)
plt.ylim(bottom=0, top=350)
apo_stream = np.append(apo_stream,np.max(data[:,2][i:]))
peri_stream = np.append(peri_stream,np.min(data[:,2][i:]))
plt.legend()
plt.savefig('/Users/oonaghparker/Downloads/DISSO/orbitplot.png')

# %%
apo_stream = []
apo_shell = []
peri_stream = []
peri_shell = []

plt.figure(figsize=(10,7))

for cid1 in stream_arr:
    data = np.genfromtxt('/Users/oonaghparker/Downloads/DISSO/22/orbit_22_{0}.txt'.format(cid1))
    plt.plot(data[:,1]-data[:,1][-1],data[:,2],c='b')
    for i in range(1,len(data)-1,1):
        if data[:,2][i] < data[:,2][i-1] and data[:,2][i] < data[:,2][i+1]:
            break
    apo_stream = np.append(apo_stream,np.max(data[:,2][i:]))
    peri_stream = np.append(peri_stream,np.min(data[:,2][i:]))
    
for cid1 in shell_arr:
    data = np.genfromtxt('/Users/oonaghparker/Downloads/DISSO/22/orbit_22_{0}.txt'.format(cid1))
    plt.plot(data[:,1]-data[:,1][-1],data[:,2],c='r')
    for i in range(1,len(data)-1,1):
        if data[:,2][i] < data[:,2][i-1] and data[:,2][i] < data[:,2][i+1]:
            break
    apo_shell = np.append(apo_shell,np.max(data[:,2][i:]))
    peri_shell = np.append(peri_shell,np.min(data[:,2][i:]))    
    
data = np.genfromtxt('/Users/oonaghparker/Downloads/DISSO/22/orbit_22_1.txt'.format(cid1))
plt.plot(data[:,1]-data[:,1][-1],data[:,2],c='b',label='Stream')
plt.xlabel('Lookback Time (Gyr)', fontsize=15)
plt.ylabel('Radius (kpc)', fontsize=15)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.xlim(left=-9.77, right=0)
plt.ylim(bottom=0, top=350)

data2 = np.genfromtxt('/Users/oonaghparker/Downloads/DISSO/22/orbit_22_2.txt'.format(cid1))
plt.plot(data2[:,1]-data2[:,1][-1],data2[:,2],c='r',label='Shell')
plt.xlabel('Lookback Time (Gyr)', fontsize=15)
plt.ylabel('Radius (kpc)', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlim(left=-9.77, right=0)
plt.ylim(bottom=0, top=350)
plt.legend()
plt.savefig('/Users/oonaghparker/Downloads/DISSO/orbitplot.png')

# %%
ecc_stream = (apo_stream-peri_stream)/(apo_stream+peri_stream)
ecc_shell = (apo_shell-peri_shell)/(apo_shell+peri_shell)

# %%
plt.figure(figsize=(10,7))
plt.hist(ecc_stream,color='b', bins=15, label='Streams', alpha=0.7)
plt.hist(ecc_shell,color='r',bins=15, label='Shells', alpha=0.7)
plt.legend()
plt.xlabel('Eccentricity', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig('/Users/oonaghparker/Downloads/DISSO/orbithistogram.png')
